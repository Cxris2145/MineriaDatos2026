# %% [markdown]
# <a href="https://colab.research.google.com/github/Cxris2145/MineriaDatos2026/blob/main/Copia_de_ExportacionesChile2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/datasets/michallublin/chile-export-products-20172021

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Para ver todas las columnas sin cortes
pd.set_option('display.max_columns', None)

# Para ver todas las filas (cuidado si el dataset es muy grande)
pd.set_option('display.max_rows', None)

# %%
import pandas as pd

# Carga de datos
df = pd.read_csv("ChileExport.csv", sep=';')
df.head()
# Out:
#   Country 1 category 2 category                                    Product  \
# 0   China     Minero    Minería      Minerales de cobre y sus concentrados
# 1   China     Minero    Minería                                      Cobre
# 2   China     Minero    Minería     Minerales de hierro y sus concentrados
# 3   China     Minero    Minería                                      Litio
# 4   China     Minero    Minería  Minerales de molibdeno y sus concentrados
#
#    Year Income in USD
# 0  2017    6470444174
# 1  2017    7604230274
# 2  2017   616711446,1
# 3  2017     234218255
# 4  2017   37490057,93

# %%
df_anio = df["Year"].describe()
print(df_anio)
# Out:
# count    21385.000000
# mean      2019.000000
# std          1.414247
# min       2017.000000
# 25%       2018.000000
# 50%       2019.000000
# 75%       2020.000000
# max       2021.000000
# Name: Year, dtype: float64

# %%
df_country = df["Country"].value_counts()
print(df_country)
# Out:
# Country
# Estados Unidos de América                              355
# China                                                  350
# Japón                                                  335
# Perú                                                   335
# Brasil                                                 330
# Canadá                                                 330
# España                                                 330
# Alemania                                               315
# Colombia                                               315
# México                                                 310
# Holanda                                                305
# Corea del Sur                                          305
# Italia                                                 300
# Reino Unido                                            295
# Argentina                                              295
# Bélgica                                                280
# ...
